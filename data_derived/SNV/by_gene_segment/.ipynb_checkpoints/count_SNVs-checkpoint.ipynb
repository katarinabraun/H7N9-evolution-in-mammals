# %% [markdown]
# ### this is a little script to count the number of SNVs by virus group as well as by synonymous vs nonsynonymous status

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
# ferret 1

PB2_syn_1 = pd.read_csv('1/PB2__syn.csv', sep='\t')
PB2_syn_1_len = len(PB2_syn_1)
PB1_syn_1 = pd.read_csv('1/PB1__syn.csv', sep='\t')
PB1_syn_1_len = len(PB1_syn_1)
PA_syn_1 = pd.read_csv('1/PA__syn.csv', sep='\t')
PA_syn_1_len = len(PA_syn_1)
HA_syn_1 = pd.read_csv('1/HA__syn.csv', sep='\t')
HA_syn_1_len = len(HA_syn_1)
NP_syn_1 = pd.read_csv('1/NP__syn.csv', sep='\t')
NP_syn_1_len = len(NP_syn_1)
NA_syn_1 = pd.read_csv('1/NA__syn.csv', sep='\t')
NA_syn_1_len = len(NA_syn_1)
M1_syn_1 = pd.read_csv('1/M1__syn.csv', sep='\t')
M1_syn_1_len = len(M1_syn_1)
# M2_syn_1 = pd.read_csv('1/M2__syn.csv', sep='\t')
# M2_syn_1_len = len(M2_syn_1)
NS1_syn_1 = pd.read_csv('1/NS1__syn.csv', sep='\t')
NS1_syn_1_len = len(NS1_syn_1)
# NEP_syn_1 = pd.read_csv('1/NEP__syn.csv', sep='\t')
# NEP_syn_1_len = len(NEP_syn_1)

PB2_nonsyn_1 = pd.read_csv('1/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_1_len = len(PB2_nonsyn_1)
PB1_nonsyn_1 = pd.read_csv('1/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_1_len = len(PB1_nonsyn_1)
PA_nonsyn_1 = pd.read_csv('1/PA__nonsyn.csv', sep='\t')
PA_nonsyn_1_len = len(PA_nonsyn_1)
HA_nonsyn_1 = pd.read_csv('1/HA__nonsyn.csv', sep='\t')
HA_nonsyn_1_len = len(HA_nonsyn_1)
NP_nonsyn_1 = pd.read_csv('1/NP__nonsyn.csv', sep='\t')
NP_nonsyn_1_len = len(NP_nonsyn_1)
NA_nonsyn_1 = pd.read_csv('1/NA__nonsyn.csv', sep='\t')
NA_nonsyn_1_len = len(NA_nonsyn_1)
M1_nonsyn_1 = pd.read_csv('1/M1__nonsyn.csv', sep='\t')
M1_nonsyn_1_len = len(M1_nonsyn_1)
# M2_nonsyn_1 = pd.read_csv('1/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_1_len = len(M2_nonsyn_1)
NS1_nonsyn_1 = pd.read_csv('1/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_1_len = len(NS1_nonsyn_1)
NEP_nonsyn_1 = pd.read_csv('1/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_1_len = len(NEP_nonsyn_1)

syn_total_1 = PB2_syn_1_len + PB1_syn_1_len + PA_syn_1_len + HA_syn_1_len + NP_syn_1_len + NA_syn_1_len + M1_syn_1_len + NS1_syn_1_len 
nonsyn_total_1 = PB2_nonsyn_1_len + PB1_nonsyn_1_len + PA_nonsyn_1_len + HA_nonsyn_1_len + NP_nonsyn_1_len + NA_nonsyn_1_len + M1_nonsyn_1_len + NS1_nonsyn_1_len + NEP_nonsyn_1_len

print(syn_total_1)
print(nonsyn_total_1)
##
# Out:
# 69
# 52

# %%
# ferret 3

PB2_syn_3 = pd.read_csv('3/PB2__syn.csv', sep='\t')
PB2_syn_3_len = len(PB2_syn_3)
PB1_syn_3 = pd.read_csv('3/PB1__syn.csv', sep='\t')
PB1_syn_3_len = len(PB1_syn_3)
PA_syn_3 = pd.read_csv('3/PA__syn.csv', sep='\t')
PA_syn_3_len = len(PA_syn_3)
HA_syn_3 = pd.read_csv('3/HA__syn.csv', sep='\t')
HA_syn_3_len = len(HA_syn_3)
NP_syn_3 = pd.read_csv('3/NP__syn.csv', sep='\t')
NP_syn_3_len = len(NP_syn_3)
NA_syn_3 = pd.read_csv('3/NA__syn.csv', sep='\t')
NA_syn_3_len = len(NA_syn_3)
M1_syn_3 = pd.read_csv('3/M1__syn.csv', sep='\t')
M1_syn_3_len = len(M1_syn_3)
# M2_syn_3 = pd.read_csv('3/M2__syn.csv', sep='\t')
# M2_syn_3_len = len(M2_syn_3)
NS1_syn_3 = pd.read_csv('3/NS1__syn.csv', sep='\t')
NS1_syn_3_len = len(NS1_syn_3)
NEP_syn_3 = pd.read_csv('3/NEP__syn.csv', sep='\t')
NEP_syn_3_len = len(NEP_syn_3)

PB2_nonsyn_3 = pd.read_csv('3/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_3_len = len(PB2_nonsyn_3)
PB1_nonsyn_3 = pd.read_csv('3/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_3_len = len(PB1_nonsyn_3)
PA_nonsyn_3 = pd.read_csv('3/PA__nonsyn.csv', sep='\t')
PA_nonsyn_3_len = len(PA_nonsyn_3)
HA_nonsyn_3 = pd.read_csv('3/HA__nonsyn.csv', sep='\t')
HA_nonsyn_3_len = len(HA_nonsyn_3)
NP_nonsyn_3 = pd.read_csv('3/NP__nonsyn.csv', sep='\t')
NP_nonsyn_3_len = len(NP_nonsyn_3)
NA_nonsyn_3 = pd.read_csv('3/NA__nonsyn.csv', sep='\t')
NA_nonsyn_3_len = len(NA_nonsyn_3)
M1_nonsyn_3 = pd.read_csv('3/M1__nonsyn.csv', sep='\t')
M1_nonsyn_3_len = len(M1_nonsyn_3)
# M2_nonsyn_3 = pd.read_csv('3/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_3_len = len(M2_nonsyn_3)
NS1_nonsyn_3 = pd.read_csv('3/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_3_len = len(NS1_nonsyn_3)
NEP_nonsyn_3 = pd.read_csv('3/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_3_len = len(NEP_nonsyn_3)

syn_total_3 = PB2_syn_3_len + PB1_syn_3_len + PA_syn_3_len + HA_syn_3_len + NP_syn_3_len + NA_syn_3_len + M1_syn_3_len + NS1_syn_3_len + NEP_syn_3_len
nonsyn_total_3 = PB2_nonsyn_3_len + PB1_nonsyn_3_len + PA_nonsyn_3_len + HA_nonsyn_3_len + NP_nonsyn_3_len + NA_nonsyn_3_len  + NS1_nonsyn_3_len + NEP_nonsyn_3_len

print(syn_total_3)
print(nonsyn_total_3)
##
# Out:
# 80
# 53

# %%
# ferret 4

PB2_syn_4 = pd.read_csv('4/PB2__syn.csv', sep='\t')
PB2_syn_4_len = len(PB2_syn_4)
PB1_syn_4 = pd.read_csv('4/PB1__syn.csv', sep='\t')
PB1_syn_4_len = len(PB1_syn_4)
PA_syn_4 = pd.read_csv('4/PA__syn.csv', sep='\t')
PA_syn_4_len = len(PA_syn_4)
HA_syn_4 = pd.read_csv('4/HA__syn.csv', sep='\t')
HA_syn_4_len = len(HA_syn_4)
NP_syn_4 = pd.read_csv('4/NP__syn.csv', sep='\t')
NP_syn_4_len = len(NP_syn_4)
NA_syn_4 = pd.read_csv('4/NA__syn.csv', sep='\t')
NA_syn_4_len = len(NA_syn_4)
M1_syn_4 = pd.read_csv('4/M1__syn.csv', sep='\t')
M1_syn_4_len = len(M1_syn_4)
# M2_syn_4 = pd.read_csv('4/M2__syn.csv', sep='\t')
# M2_syn_4_len = len(M2_syn_4)
NS1_syn_4 = pd.read_csv('4/NS1__syn.csv', sep='\t')
NS1_syn_4_len = len(NS1_syn_4)
# NEP_syn_4 = pd.read_csv('4/NEP__syn.csv', sep='\t')
# NEP_syn_4_len = len(NEP_syn_4)

PB2_nonsyn_4 = pd.read_csv('4/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_4_len = len(PB2_nonsyn_4)
PB1_nonsyn_4 = pd.read_csv('4/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_4_len = len(PB1_nonsyn_4)
PA_nonsyn_4 = pd.read_csv('4/PA__nonsyn.csv', sep='\t')
PA_nonsyn_4_len = len(PA_nonsyn_4)
HA_nonsyn_4 = pd.read_csv('4/HA__nonsyn.csv', sep='\t')
HA_nonsyn_4_len = len(HA_nonsyn_4)
NP_nonsyn_4 = pd.read_csv('4/NP__nonsyn.csv', sep='\t')
NP_nonsyn_4_len = len(NP_nonsyn_4)
NA_nonsyn_4 = pd.read_csv('4/NA__nonsyn.csv', sep='\t')
NA_nonsyn_4_len = len(NA_nonsyn_4)
M1_nonsyn_4 = pd.read_csv('4/M1__nonsyn.csv', sep='\t')
M1_nonsyn_4_len = len(M1_nonsyn_4)
# M2_nonsyn_4 = pd.read_csv('4/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_4_len = len(M2_nonsyn_4)
NS1_nonsyn_4 = pd.read_csv('4/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_4_len = len(NS1_nonsyn_4)
NEP_nonsyn_4 = pd.read_csv('4/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_4_len = len(NEP_nonsyn_4)

syn_total_4 = PB2_syn_4_len + PB1_syn_4_len + PA_syn_4_len + HA_syn_4_len + NP_syn_4_len + NA_syn_4_len + M1_syn_4_len + NS1_syn_4_len
nonsyn_total_4 = PB2_nonsyn_4_len + PB1_nonsyn_4_len + PA_nonsyn_4_len + HA_nonsyn_4_len + NP_nonsyn_4_len + NA_nonsyn_4_len + M1_nonsyn_4_len + NS1_nonsyn_4_len + NEP_nonsyn_4_len

print(syn_total_4)
print(nonsyn_total_4)
##
# Out:
# 18
# 15

# %%
# ferret 5

PB2_syn_5 = pd.read_csv('5/PB2__syn.csv', sep='\t')
PB2_syn_5_len = len(PB2_syn_5)
PB1_syn_5 = pd.read_csv('5/PB1__syn.csv', sep='\t')
PB1_syn_5_len = len(PB1_syn_5)
PA_syn_5 = pd.read_csv('5/PA__syn.csv', sep='\t')
PA_syn_5_len = len(PA_syn_5)
HA_syn_5 = pd.read_csv('5/HA__syn.csv', sep='\t')
HA_syn_5_len = len(HA_syn_5)
NP_syn_5 = pd.read_csv('5/NP__syn.csv', sep='\t')
NP_syn_5_len = len(NP_syn_5)
NA_syn_5 = pd.read_csv('5/NA__syn.csv', sep='\t')
NA_syn_5_len = len(NA_syn_5)
M1_syn_5 = pd.read_csv('5/M1__syn.csv', sep='\t')
M1_syn_5_len = len(M1_syn_5)
# M2_syn_5 = pd.read_csv('5/M2__syn.csv', sep='\t')
# M2_syn_5_len = len(M2_syn_5)
NS1_syn_5 = pd.read_csv('5/NS1__syn.csv', sep='\t')
NS1_syn_5_len = len(NS1_syn_5)
NEP_syn_5 = pd.read_csv('5/NEP__syn.csv', sep='\t')
NEP_syn_5_len = len(NEP_syn_5)

PB2_nonsyn_5 = pd.read_csv('5/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_5_len = len(PB2_nonsyn_5)
PB1_nonsyn_5 = pd.read_csv('5/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_5_len = len(PB1_nonsyn_5)
PA_nonsyn_5 = pd.read_csv('5/PA__nonsyn.csv', sep='\t')
PA_nonsyn_5_len = len(PA_nonsyn_5)
HA_nonsyn_5 = pd.read_csv('5/HA__nonsyn.csv', sep='\t')
HA_nonsyn_5_len = len(HA_nonsyn_5)
NP_nonsyn_5 = pd.read_csv('5/NP__nonsyn.csv', sep='\t')
NP_nonsyn_5_len = len(NP_nonsyn_5)
NA_nonsyn_5 = pd.read_csv('5/NA__nonsyn.csv', sep='\t')
NA_nonsyn_5_len = len(NA_nonsyn_5)
M1_nonsyn_5 = pd.read_csv('5/M1__nonsyn.csv', sep='\t')
M1_nonsyn_5_len = len(M1_nonsyn_5)
# M2_nonsyn_5 = pd.read_csv('5/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_5_len = len(M2_nonsyn_5)
NS1_nonsyn_5 = pd.read_csv('5/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_5_len = len(NS1_nonsyn_5)
NEP_nonsyn_5 = pd.read_csv('5/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_5_len = len(NEP_nonsyn_5)

syn_total_5 = PB2_syn_5_len + PB1_syn_5_len + PA_syn_5_len + HA_syn_5_len + NP_syn_5_len + NA_syn_5_len + M1_syn_5_len + NS1_syn_5_len + NEP_syn_5_len
nonsyn_total_5 = PB2_nonsyn_5_len + PB1_nonsyn_5_len + PA_nonsyn_5_len + HA_nonsyn_5_len + NP_nonsyn_5_len + NA_nonsyn_5_len + M1_nonsyn_5_len + NS1_nonsyn_5_len + NEP_nonsyn_5_len

print(syn_total_5)
print(nonsyn_total_5)
##
# Out:
# 65
# 54

# %%
# ferret 7

PB2_syn_7 = pd.read_csv('7/PB2__syn.csv', sep='\t')
PB2_syn_7_len = len(PB2_syn_7)
PB1_syn_7 = pd.read_csv('7/PB1__syn.csv', sep='\t')
PB1_syn_7_len = len(PB1_syn_7)
PA_syn_7 = pd.read_csv('7/PA__syn.csv', sep='\t')
PA_syn_7_len = len(PA_syn_7)
HA_syn_7 = pd.read_csv('7/HA__syn.csv', sep='\t')
HA_syn_7_len = len(HA_syn_7)
NP_syn_7 = pd.read_csv('7/NP__syn.csv', sep='\t')
NP_syn_7_len = len(NP_syn_7)
NA_syn_7 = pd.read_csv('7/NA__syn.csv', sep='\t')
NA_syn_7_len = len(NA_syn_7)
M1_syn_7 = pd.read_csv('7/M1__syn.csv', sep='\t')
M1_syn_7_len = len(M1_syn_7)
M2_syn_7 = pd.read_csv('7/M2__syn.csv', sep='\t')
M2_syn_7_len = len(M2_syn_7)
NS1_syn_7 = pd.read_csv('7/NS1__syn.csv', sep='\t')
NS1_syn_7_len = len(NS1_syn_7)
# NEP_syn_7 = pd.read_csv('7/NEP__syn.csv', sep='\t')
# NEP_syn_7_len = len(NEP_syn_7)

PB2_nonsyn_7 = pd.read_csv('7/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_7_len = len(PB2_nonsyn_7)
PB1_nonsyn_7 = pd.read_csv('7/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_7_len = len(PB1_nonsyn_7)
PA_nonsyn_7 = pd.read_csv('7/PA__nonsyn.csv', sep='\t')
PA_nonsyn_7_len = len(PA_nonsyn_7)
HA_nonsyn_7 = pd.read_csv('7/HA__nonsyn.csv', sep='\t')
HA_nonsyn_7_len = len(HA_nonsyn_7)
NP_nonsyn_7 = pd.read_csv('7/NP__nonsyn.csv', sep='\t')
NP_nonsyn_7_len = len(NP_nonsyn_7)
NA_nonsyn_7 = pd.read_csv('7/NA__nonsyn.csv', sep='\t')
NA_nonsyn_7_len = len(NA_nonsyn_7)
M1_nonsyn_7 = pd.read_csv('7/M1__nonsyn.csv', sep='\t')
M1_nonsyn_7_len = len(M1_nonsyn_7)
M2_nonsyn_7 = pd.read_csv('7/M2__nonsyn.csv', sep='\t')
M2_nonsyn_7_len = len(M2_nonsyn_7)
NS1_nonsyn_7 = pd.read_csv('7/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_7_len = len(NS1_nonsyn_7)
NEP_nonsyn_7 = pd.read_csv('7/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_7_len = len(NEP_nonsyn_7)

syn_total_7 = PB2_syn_7_len + PB1_syn_7_len + PA_syn_7_len + HA_syn_7_len + NP_syn_7_len + NA_syn_7_len + M1_syn_7_len + M2_syn_7_len + NS1_syn_7_len
nonsyn_total_7 = PB2_nonsyn_7_len + PB1_nonsyn_7_len + PA_nonsyn_7_len + HA_nonsyn_7_len + NP_nonsyn_7_len + NA_nonsyn_7_len + M1_nonsyn_7_len + M2_nonsyn_7_len + NS1_nonsyn_7_len + NEP_nonsyn_7_len

print(syn_total_7)
print(nonsyn_total_7)
##
# Out:
# 79
# 64

# %%
# ferret 9

# PB2_syn_9 = pd.read_csv('9/PB2__syn.csv', sep='\t')
# PB2_syn_9_len = len(PB2_syn_9)
# PB1_syn_9 = pd.read_csv('9/PB1__syn.csv', sep='\t')
# PB1_syn_9_len = len(PB1_syn_9)
PA_syn_9 = pd.read_csv('9/PA__syn.csv', sep='\t')
PA_syn_9_len = len(PA_syn_9)
HA_syn_9 = pd.read_csv('9/HA__syn.csv', sep='\t')
HA_syn_9_len = len(HA_syn_9)
NP_syn_9 = pd.read_csv('9/NP__syn.csv', sep='\t')
NP_syn_9_len = len(NP_syn_9)
NA_syn_9 = pd.read_csv('9/NA__syn.csv', sep='\t')
NA_syn_9_len = len(NA_syn_9)
M1_syn_9 = pd.read_csv('9/M1__syn.csv', sep='\t')
M1_syn_9_len = len(M1_syn_9)
# M2_syn_9 = pd.read_csv('9/M2__syn.csv', sep='\t')
# M2_syn_9_len = len(M2_syn_9)
# NS1_syn_9 = pd.read_csv('9/NS1__syn.csv', sep='\t')
# NS1_syn_9_len = len(NS1_syn_9)
# NEP_syn_9 = pd.read_csv('9/NEP__syn.csv', sep='\t')
# NEP_syn_9_len = len(NEP_syn_9)

PB2_nonsyn_9 = pd.read_csv('9/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_9_len = len(PB2_nonsyn_9)
# PB1_nonsyn_9 = pd.read_csv('9/PB1__nonsyn.csv', sep='\t')
# PB1_nonsyn_9_len = len(PB1_nonsyn_9)
# PA_nonsyn_9 = pd.read_csv('9/PA__nonsyn.csv', sep='\t')
# PA_nonsyn_9_len = len(PA_nonsyn_9)
HA_nonsyn_9 = pd.read_csv('9/HA__nonsyn.csv', sep='\t')
HA_nonsyn_9_len = len(HA_nonsyn_9)
NP_nonsyn_9 = pd.read_csv('9/NP__nonsyn.csv', sep='\t')
NP_nonsyn_9_len = len(NP_nonsyn_9)
NA_nonsyn_9 = pd.read_csv('9/NA__nonsyn.csv', sep='\t')
NA_nonsyn_9_len = len(NA_nonsyn_9)
# M1_nonsyn_9 = pd.read_csv('9/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_9_len = len(M1_nonsyn_9)
M2_nonsyn_9 = pd.read_csv('9/M2__nonsyn.csv', sep='\t')
M2_nonsyn_9_len = len(M2_nonsyn_9)
# NS1_nonsyn_9 = pd.read_csv('9/NS1__nonsyn.csv', sep='\t')
# NS1_nonsyn_9_len = len(NS1_nonsyn_9)
# NEP_nonsyn_9 = pd.read_csv('9/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_9_len = len(NEP_nonsyn_9)

syn_total_9 = PA_syn_9_len + HA_syn_9_len + NP_syn_9_len + NA_syn_9_len + M1_syn_9_len
nonsyn_total_9 = PB2_nonsyn_9_len + HA_nonsyn_9_len + NP_nonsyn_9_len + NA_nonsyn_9_len + M2_nonsyn_9_len

print(syn_total_9)
print(nonsyn_total_9)
##
# Out:
# 7
# 7

# %%
# ferret 10

PB2_syn_10 = pd.read_csv('10/PB2__syn.csv', sep='\t')
PB2_syn_10_len = len(PB2_syn_10)
# PB1_syn_10 = pd.read_csv('10/PB1__syn.csv', sep='\t')
# PB1_syn_10_len = len(PB1_syn_10)
PA_syn_10 = pd.read_csv('10/PA__syn.csv', sep='\t')
PA_syn_10_len = len(PA_syn_10)
HA_syn_10 = pd.read_csv('10/HA__syn.csv', sep='\t')
HA_syn_10_len = len(HA_syn_10)
# NP_syn_10 = pd.read_csv('10/NP__syn.csv', sep='\t')
# NP_syn_10_len = len(NP_syn_10)
NA_syn_10 = pd.read_csv('10/NA__syn.csv', sep='\t')
NA_syn_10_len = len(NA_syn_10)
# M1_syn_10 = pd.read_csv('10/M1__syn.csv', sep='\t')
# M1_syn_10_len = len(M1_syn_10)
# M2_syn_10 = pd.read_csv('10/M2__syn.csv', sep='\t')
# M2_syn_10_len = len(M2_syn_10)
NS1_syn_10 = pd.read_csv('10/NS1__syn.csv', sep='\t')
NS1_syn_10_len = len(NS1_syn_10)
# NEP_syn_10 = pd.read_csv('10/NEP__syn.csv', sep='\t')
# NEP_syn_10_len = len(NEP_syn_10)

# PB2_nonsyn_10 = pd.read_csv('10/PB2__nonsyn.csv', sep='\t')
# PB2_nonsyn_10_len = len(PB2_nonsyn_10)
# PB1_nonsyn_10 = pd.read_csv('10/PB1__nonsyn.csv', sep='\t')
# PB1_nonsyn_10_len = len(PB1_nonsyn_10)
# PA_nonsyn_10 = pd.read_csv('10/PA__nonsyn.csv', sep='\t')
# PA_nonsyn_10_len = len(PA_nonsyn_10)
HA_nonsyn_10 = pd.read_csv('10/HA__nonsyn.csv', sep='\t')
HA_nonsyn_10_len = len(HA_nonsyn_10)
NP_nonsyn_10 = pd.read_csv('10/NP__nonsyn.csv', sep='\t')
NP_nonsyn_10_len = len(NP_nonsyn_10)
NA_nonsyn_10 = pd.read_csv('10/NA__nonsyn.csv', sep='\t')
NA_nonsyn_10_len = len(NA_nonsyn_10)
# M1_nonsyn_10 = pd.read_csv('10/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_10_len = len(M1_nonsyn_10)
# M2_nonsyn_10 = pd.read_csv('10/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_10_len = len(M2_nonsyn_10)
# NS1_nonsyn_10 = pd.read_csv('10/NS1__nonsyn.csv', sep='\t')
# NS1_nonsyn_10_len = len(NS1_nonsyn_10)
NEP_nonsyn_10 = pd.read_csv('10/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_10_len = len(NEP_nonsyn_10)

syn_total_10 = PB2_syn_10_len + PA_syn_10_len + HA_syn_10_len + NA_syn_10_len + NS1_syn_10_len
nonsyn_total_10 = HA_nonsyn_10_len + NP_nonsyn_10_len + NA_nonsyn_10_len + NEP_nonsyn_10_len

print(syn_total_10)
print(nonsyn_total_10)
##
# Out:
# 7
# 6

# %%
# ferret 11

# PB2_syn_11 = pd.read_csv('11/PB2__syn.csv', sep='\t')
# PB2_syn_11_len = len(PB2_syn_11)
# PB1_syn_11 = pd.read_csv('11/PB1__syn.csv', sep='\t')
# PB1_syn_11_len = len(PB1_syn_11)
PA_syn_11 = pd.read_csv('11/PA__syn.csv', sep='\t')
PA_syn_11_len = len(PA_syn_11)
HA_syn_11 = pd.read_csv('11/HA__syn.csv', sep='\t')
HA_syn_11_len = len(HA_syn_11)
# NP_syn_11 = pd.read_csv('11/NP__syn.csv', sep='\t')
# NP_syn_11_len = len(NP_syn_11)
NA_syn_11 = pd.read_csv('11/NA__syn.csv', sep='\t')
NA_syn_11_len = len(NA_syn_11)
# M1_syn_11 = pd.read_csv('11/M1__syn.csv', sep='\t')
# M1_syn_11_len = len(M1_syn_11)
# M2_syn_11 = pd.read_csv('11/M2__syn.csv', sep='\t')
# M2_syn_11_len = len(M2_syn_11)
# NS1_syn_11 = pd.read_csv('11/NS1__syn.csv', sep='\t')
# NS1_syn_11_len = len(NS1_syn_11)
# NEP_syn_11 = pd.read_csv('11/NEP__syn.csv', sep='\t')
# NEP_syn_11_len = len(NEP_syn_11)

# PB2_nonsyn_11 = pd.read_csv('11/PB2__nonsyn.csv', sep='\t')
# PB2_nonsyn_11_len = len(PB2_nonsyn_11)
# PB1_nonsyn_11 = pd.read_csv('11/PB1__nonsyn.csv', sep='\t')
# PB1_nonsyn_11_len = len(PB1_nonsyn_11)
# PA_nonsyn_11 = pd.read_csv('11/PA__nonsyn.csv', sep='\t')
# PA_nonsyn_11_len = len(PA_nonsyn_11)
HA_nonsyn_11 = pd.read_csv('11/HA__nonsyn.csv', sep='\t')
HA_nonsyn_11_len = len(HA_nonsyn_11)
# NP_nonsyn_11 = pd.read_csv('11/NP__nonsyn.csv', sep='\t')
# NP_nonsyn_11_len = len(NP_nonsyn_11)
NA_nonsyn_11 = pd.read_csv('11/NA__nonsyn.csv', sep='\t')
NA_nonsyn_11_len = len(NA_nonsyn_11)
# M1_nonsyn_11 = pd.read_csv('11/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_11_len = len(M1_nonsyn_11)
# M2_nonsyn_11 = pd.read_csv('11/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_11_len = len(M2_nonsyn_11)
# NS1_nonsyn_11 = pd.read_csv('11/NS1__nonsyn.csv', sep='\t')
# NS1_nonsyn_11_len = len(NS1_nonsyn_11)
# NEP_nonsyn_11 = pd.read_csv('11/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_11_len = len(NEP_nonsyn_11)

syn_total_11 = PA_syn_11_len + HA_syn_11_len + NA_syn_11_len
nonsyn_total_11 = HA_nonsyn_11_len + NA_nonsyn_11_len

print(syn_total_11)
print(nonsyn_total_11)
##
# Out:
# 4
# 3

# %%
# ferret 12

PB2_syn_12 = pd.read_csv('12/PB2__syn.csv', sep='\t')
PB2_syn_12_len = len(PB2_syn_12)
PB1_syn_12 = pd.read_csv('12/PB1__syn.csv', sep='\t')
PB1_syn_12_len = len(PB1_syn_12)
# PA_syn_12 = pd.read_csv('12/PA__syn.csv', sep='\t')
# PA_syn_12_len = len(PA_syn_12)
HA_syn_12 = pd.read_csv('12/HA__syn.csv', sep='\t')
HA_syn_12_len = len(HA_syn_12)
NP_syn_12 = pd.read_csv('12/NP__syn.csv', sep='\t')
NP_syn_12_len = len(NP_syn_12)
NA_syn_12 = pd.read_csv('12/NA__syn.csv', sep='\t')
NA_syn_12_len = len(NA_syn_12)
# M1_syn_12 = pd.read_csv('12/M1__syn.csv', sep='\t')
# M1_syn_12_len = len(M1_syn_12)
# M2_syn_12 = pd.read_csv('12/M2__syn.csv', sep='\t')
# M2_syn_12_len = len(M2_syn_12)
# NS1_syn_12 = pd.read_csv('12/NS1__syn.csv', sep='\t')
# NS1_syn_12_len = len(NS1_syn_12)
# NEP_syn_12 = pd.read_csv('12/NEP__syn.csv', sep='\t')
# NEP_syn_12_len = len(NEP_syn_12)

# PB2_nonsyn_12 = pd.read_csv('12/PB2__nonsyn.csv', sep='\t')
# PB2_nonsyn_12_len = len(PB2_nonsyn_12)
PB1_nonsyn_12 = pd.read_csv('12/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_12_len = len(PB1_nonsyn_12)
# PA_nonsyn_12 = pd.read_csv('12/PA__nonsyn.csv', sep='\t')
# PA_nonsyn_12_len = len(PA_nonsyn_12)
HA_nonsyn_12 = pd.read_csv('12/HA__nonsyn.csv', sep='\t')
HA_nonsyn_12_len = len(HA_nonsyn_12)
# NP_nonsyn_12 = pd.read_csv('12/NP__nonsyn.csv', sep='\t')
# NP_nonsyn_12_len = len(NP_nonsyn_12)
NA_nonsyn_12 = pd.read_csv('12/NA__nonsyn.csv', sep='\t')
NA_nonsyn_12_len = len(NA_nonsyn_12)
# M1_nonsyn_12 = pd.read_csv('12/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_12_len = len(M1_nonsyn_12)
# M2_nonsyn_12 = pd.read_csv('12/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_12_len = len(M2_nonsyn_12)
# NS1_nonsyn_12 = pd.read_csv('12/NS1__nonsyn.csv', sep='\t')
# NS1_nonsyn_12_len = len(NS1_nonsyn_12)
# NEP_nonsyn_12 = pd.read_csv('12/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_12_len = len(NEP_nonsyn_12)

syn_total_12 = PB2_syn_12_len + PB1_syn_12_len + HA_syn_12_len + NP_syn_12_len + NA_syn_12_len
nonsyn_total_12 = PB1_nonsyn_12_len + HA_nonsyn_12_len + NA_nonsyn_12_len

print(syn_total_12)
print(nonsyn_total_12)
##
# Out:
# 6
# 4

# %%
# ferret 13

PB2_syn_13 = pd.read_csv('13/PB2__syn.csv', sep='\t')
PB2_syn_13_len = len(PB2_syn_13)
# PB1_syn_13 = pd.read_csv('13/PB1__syn.csv', sep='\t')
# PB1_syn_13_len = len(PB1_syn_13)
# PA_syn_13 = pd.read_csv('13/PA__syn.csv', sep='\t')
# PA_syn_13_len = len(PA_syn_13)
HA_syn_13 = pd.read_csv('13/HA__syn.csv', sep='\t')
HA_syn_13_len = len(HA_syn_13)
# NP_syn_13 = pd.read_csv('13/NP__syn.csv', sep='\t')
# NP_syn_13_len = len(NP_syn_13)
NA_syn_13 = pd.read_csv('13/NA__syn.csv', sep='\t')
NA_syn_13_len = len(NA_syn_13)
# M1_syn_13 = pd.read_csv('13/M1__syn.csv', sep='\t')
# M1_syn_13_len = len(M1_syn_13)
# M2_syn_13 = pd.read_csv('13/M2__syn.csv', sep='\t')
# M2_syn_13_len = len(M2_syn_13)
# NS1_syn_13 = pd.read_csv('13/NS1__syn.csv', sep='\t')
# NS1_syn_13_len = len(NS1_syn_13)
# NEP_syn_13 = pd.read_csv('13/NEP__syn.csv', sep='\t')
# NEP_syn_13_len = len(NEP_syn_13)

# PB2_nonsyn_13 = pd.read_csv('13/PB2__nonsyn.csv', sep='\t')
# PB2_nonsyn_13_len = len(PB2_nonsyn_13)
PB1_nonsyn_13 = pd.read_csv('13/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_13_len = len(PB1_nonsyn_13)
# PA_nonsyn_13 = pd.read_csv('13/PA__nonsyn.csv', sep='\t')
# PA_nonsyn_13_len = len(PA_nonsyn_13)
HA_nonsyn_13 = pd.read_csv('13/HA__nonsyn.csv', sep='\t')
HA_nonsyn_13_len = len(HA_nonsyn_13)
# NP_nonsyn_13 = pd.read_csv('13/NP__nonsyn.csv', sep='\t')
# NP_nonsyn_13_len = len(NP_nonsyn_13)
NA_nonsyn_13 = pd.read_csv('13/NA__nonsyn.csv', sep='\t')
NA_nonsyn_13_len = len(NA_nonsyn_13)
M1_nonsyn_13 = pd.read_csv('13/M1__nonsyn.csv', sep='\t')
M1_nonsyn_13_len = len(M1_nonsyn_13)
# M2_nonsyn_13 = pd.read_csv('13/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_13_len = len(M2_nonsyn_13)
# NS1_nonsyn_13 = pd.read_csv('13/NS1__nonsyn.csv', sep='\t')
# NS1_nonsyn_13_len = len(NS1_nonsyn_13)
# NEP_nonsyn_13 = pd.read_csv('13/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_13_len = len(NEP_nonsyn_13)

syn_total_13 = PB2_syn_13_len + HA_syn_13_len + NA_syn_13_len
nonsyn_total_13 = PB1_nonsyn_13_len + HA_nonsyn_13_len + NA_nonsyn_13_len + M1_nonsyn_13_len

print(syn_total_13)
print(nonsyn_total_13)
##
# Out:
# 4
# 5

# %%
# ferret 15

# PB2_syn_15 = pd.read_csv('15/PB2__syn.csv', sep='\t')
# PB2_syn_15_len = len(PB2_syn_15)
# PB1_syn_15 = pd.read_csv('15/PB1__syn.csv', sep='\t')
# PB1_syn_15_len = len(PB1_syn_15)
PA_syn_15 = pd.read_csv('15/PA__syn.csv', sep='\t')
PA_syn_15_len = len(PA_syn_15)
HA_syn_15 = pd.read_csv('15/HA__syn.csv', sep='\t')
HA_syn_15_len = len(HA_syn_15)
# NP_syn_15 = pd.read_csv('15/NP__syn.csv', sep='\t')
# NP_syn_15_len = len(NP_syn_15)
NA_syn_15 = pd.read_csv('15/NA__syn.csv', sep='\t')
NA_syn_15_len = len(NA_syn_15)
# M1_syn_15 = pd.read_csv('15/M1__syn.csv', sep='\t')
# M1_syn_15_len = len(M1_syn_15)
# M2_syn_15 = pd.read_csv('15/M2__syn.csv', sep='\t')
# M2_syn_15_len = len(M2_syn_15)
# NS1_syn_15 = pd.read_csv('15/NS1__syn.csv', sep='\t')
# NS1_syn_15_len = len(NS1_syn_15)
# NEP_syn_15 = pd.read_csv('15/NEP__syn.csv', sep='\t')
# NEP_syn_15_len = len(NEP_syn_15)

PB2_nonsyn_15 = pd.read_csv('15/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_15_len = len(PB2_nonsyn_15)
PB1_nonsyn_15 = pd.read_csv('15/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_15_len = len(PB1_nonsyn_15)
PA_nonsyn_15 = pd.read_csv('15/PA__nonsyn.csv', sep='\t')
PA_nonsyn_15_len = len(PA_nonsyn_15)
HA_nonsyn_15 = pd.read_csv('15/HA__nonsyn.csv', sep='\t')
HA_nonsyn_15_len = len(HA_nonsyn_15)
# NP_nonsyn_15 = pd.read_csv('15/NP__nonsyn.csv', sep='\t')
# NP_nonsyn_15_len = len(NP_nonsyn_15)
NA_nonsyn_15 = pd.read_csv('15/NA__nonsyn.csv', sep='\t')
NA_nonsyn_15_len = len(NA_nonsyn_15)
# M1_nonsyn_15 = pd.read_csv('15/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_15_len = len(M1_nonsyn_15)
# M2_nonsyn_15 = pd.read_csv('15/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_15_len = len(M2_nonsyn_15)
# NS1_nonsyn_15 = pd.read_csv('15/NS1__nonsyn.csv', sep='\t')
# NS1_nonsyn_15_len = len(NS1_nonsyn_15)
# NEP_nonsyn_15 = pd.read_csv('15/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_15_len = len(NEP_nonsyn_15)

syn_total_15 = PA_syn_15_len + HA_syn_15_len + NA_syn_15_len
nonsyn_total_15 = PB2_nonsyn_15_len + PB1_nonsyn_15_len + PA_nonsyn_15_len + HA_nonsyn_15_len + NA_nonsyn_15_len

print(syn_total_15)
print(nonsyn_total_15)
##
# Out:
# 4
# 12

# %%
# ferret 16

# PB2_syn_16 = pd.read_csv('16/PB2__syn.csv', sep='\t')
# PB2_syn_16_len = len(PB2_syn_16)
PB1_syn_16 = pd.read_csv('16/PB1__syn.csv', sep='\t')
PB1_syn_16_len = len(PB1_syn_16)
# PA_syn_16 = pd.read_csv('16/PA__syn.csv', sep='\t')
# PA_syn_16_len = len(PA_syn_16)
HA_syn_16 = pd.read_csv('16/HA__syn.csv', sep='\t')
HA_syn_16_len = len(HA_syn_16)
# NP_syn_16 = pd.read_csv('16/NP__syn.csv', sep='\t')
# NP_syn_16_len = len(NP_syn_16)
NA_syn_16 = pd.read_csv('16/NA__syn.csv', sep='\t')
NA_syn_16_len = len(NA_syn_16)
M1_syn_16 = pd.read_csv('16/M1__syn.csv', sep='\t')
M1_syn_16_len = len(M1_syn_16)
# M2_syn_16 = pd.read_csv('16/M2__syn.csv', sep='\t')
# M2_syn_16_len = len(M2_syn_16)
# NS1_syn_16 = pd.read_csv('16/NS1__syn.csv', sep='\t')
# NS1_syn_16_len = len(NS1_syn_16)
NEP_syn_16 = pd.read_csv('16/NEP__syn.csv', sep='\t')
NEP_syn_16_len = len(NEP_syn_16)

PB2_nonsyn_16 = pd.read_csv('16/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_16_len = len(PB2_nonsyn_16)
# PB1_nonsyn_16 = pd.read_csv('16/PB1__nonsyn.csv', sep='\t')
# PB1_nonsyn_16_len = len(PB1_nonsyn_16)
# PA_nonsyn_16 = pd.read_csv('16/PA__nonsyn.csv', sep='\t')
# PA_nonsyn_16_len = len(PA_nonsyn_16)
HA_nonsyn_16 = pd.read_csv('16/HA__nonsyn.csv', sep='\t')
HA_nonsyn_16_len = len(HA_nonsyn_16)
# NP_nonsyn_16 = pd.read_csv('16/NP__nonsyn.csv', sep='\t')
# NP_nonsyn_16_len = len(NP_nonsyn_16)
NA_nonsyn_16 = pd.read_csv('16/NA__nonsyn.csv', sep='\t')
NA_nonsyn_16_len = len(NA_nonsyn_16)
# M1_nonsyn_16 = pd.read_csv('16/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_16_len = len(M1_nonsyn_16)
# M2_nonsyn_16 = pd.read_csv('16/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_16_len = len(M2_nonsyn_16)
# NS1_nonsyn_16 = pd.read_csv('16/NS1__nonsyn.csv', sep='\t')
# NS1_nonsyn_16_len = len(NS1_nonsyn_16)
# NEP_nonsyn_16 = pd.read_csv('16/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_16_len = len(NEP_nonsyn_16)

syn_total_16 = PB1_syn_16_len + HA_syn_16_len + NA_syn_16_len + M1_syn_16_len + NEP_syn_16_len
nonsyn_total_16 = PB2_nonsyn_16_len + HA_nonsyn_16_len + NA_nonsyn_16_len

print(syn_total_16)
print(nonsyn_total_16)
##
# Out:
# 7
# 7

# %%
# ferret 17

PB2_syn_17 = pd.read_csv('17/PB2__syn.csv', sep='\t')
PB2_syn_17_len = len(PB2_syn_17)
PB1_syn_17 = pd.read_csv('17/PB1__syn.csv', sep='\t')
PB1_syn_17_len = len(PB1_syn_17)
# PA_syn_17 = pd.read_csv('17/PA__syn.csv', sep='\t')
# PA_syn_17_len = len(PA_syn_17)
HA_syn_17 = pd.read_csv('17/HA__syn.csv', sep='\t')
HA_syn_17_len = len(HA_syn_17)
# NP_syn_17 = pd.read_csv('17/NP__syn.csv', sep='\t')
# NP_syn_17_len = len(NP_syn_17)
NA_syn_17 = pd.read_csv('17/NA__syn.csv', sep='\t')
NA_syn_17_len = len(NA_syn_17)
# M1_syn_17 = pd.read_csv('17/M1__syn.csv', sep='\t')
# M1_syn_17_len = len(M1_syn_17)
# M2_syn_17 = pd.read_csv('17/M2__syn.csv', sep='\t')
# M2_syn_17_len = len(M2_syn_17)
NS1_syn_17 = pd.read_csv('17/NS1__syn.csv', sep='\t')
NS1_syn_17_len = len(NS1_syn_17)
# NEP_syn_17 = pd.read_csv('17/NEP__syn.csv', sep='\t')
# NEP_syn_17_len = len(NEP_syn_17)

PB2_nonsyn_17 = pd.read_csv('17/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_17_len = len(PB2_nonsyn_17)
PB1_nonsyn_17 = pd.read_csv('17/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_17_len = len(PB1_nonsyn_17)
PA_nonsyn_17 = pd.read_csv('17/PA__nonsyn.csv', sep='\t')
PA_nonsyn_17_len = len(PA_nonsyn_17)
HA_nonsyn_17 = pd.read_csv('17/HA__nonsyn.csv', sep='\t')
HA_nonsyn_17_len = len(HA_nonsyn_17)
NP_nonsyn_17 = pd.read_csv('17/NP__nonsyn.csv', sep='\t')
NP_nonsyn_17_len = len(NP_nonsyn_17)
NA_nonsyn_17 = pd.read_csv('17/NA__nonsyn.csv', sep='\t')
NA_nonsyn_17_len = len(NA_nonsyn_17)
# M1_nonsyn_17 = pd.read_csv('17/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_17_len = len(M1_nonsyn_17)
# M2_nonsyn_17 = pd.read_csv('17/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_17_len = len(M2_nonsyn_17)
NS1_nonsyn_17 = pd.read_csv('17/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_17_len = len(NS1_nonsyn_17)
NEP_nonsyn_17 = pd.read_csv('17/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_17_len = len(NEP_nonsyn_17)

syn_total_17 = PB2_syn_17_len + PB1_syn_17_len + HA_syn_17_len + NA_syn_17_len + NS1_syn_17_len
nonsyn_total_17 = PB2_nonsyn_17_len + PB1_nonsyn_17_len + PA_nonsyn_17_len + HA_nonsyn_17_len + NP_nonsyn_17_len + NA_nonsyn_17_len + NS1_nonsyn_17_len + NEP_nonsyn_17_len

print(syn_total_17)
print(nonsyn_total_17)
##
# Out:
# 11
# 16

# %%
# ferret 18

PB2_syn_18 = pd.read_csv('18/PB2__syn.csv', sep='\t')
PB2_syn_18_len = len(PB2_syn_18)
PB1_syn_18 = pd.read_csv('18/PB1__syn.csv', sep='\t')
PB1_syn_18_len = len(PB1_syn_18)
PA_syn_18 = pd.read_csv('18/PA__syn.csv', sep='\t')
PA_syn_18_len = len(PA_syn_18)
HA_syn_18 = pd.read_csv('18/HA__syn.csv', sep='\t')
HA_syn_18_len = len(HA_syn_18)
NP_syn_18 = pd.read_csv('18/NP__syn.csv', sep='\t')
NP_syn_18_len = len(NP_syn_18)
NA_syn_18 = pd.read_csv('18/NA__syn.csv', sep='\t')
NA_syn_18_len = len(NA_syn_18)
M1_syn_18 = pd.read_csv('18/M1__syn.csv', sep='\t')
M1_syn_18_len = len(M1_syn_18)
# M2_syn_18 = pd.read_csv('18/M2__syn.csv', sep='\t')
# M2_syn_18_len = len(M2_syn_18)
NS1_syn_18 = pd.read_csv('18/NS1__syn.csv', sep='\t')
NS1_syn_18_len = len(NS1_syn_18)
NEP_syn_18 = pd.read_csv('18/NEP__syn.csv', sep='\t')
NEP_syn_18_len = len(NEP_syn_18)

PB2_nonsyn_18 = pd.read_csv('18/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_18_len = len(PB2_nonsyn_18)
PB1_nonsyn_18 = pd.read_csv('18/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_18_len = len(PB1_nonsyn_18)
PA_nonsyn_18 = pd.read_csv('18/PA__nonsyn.csv', sep='\t')
PA_nonsyn_18_len = len(PA_nonsyn_18)
HA_nonsyn_18 = pd.read_csv('18/HA__nonsyn.csv', sep='\t')
HA_nonsyn_18_len = len(HA_nonsyn_18)
NP_nonsyn_18 = pd.read_csv('18/NP__nonsyn.csv', sep='\t')
NP_nonsyn_18_len = len(NP_nonsyn_18)
NA_nonsyn_18 = pd.read_csv('18/NA__nonsyn.csv', sep='\t')
NA_nonsyn_18_len = len(NA_nonsyn_18)
# M1_nonsyn_18 = pd.read_csv('18/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_18_len = len(M1_nonsyn_18)
M2_nonsyn_18 = pd.read_csv('18/M2__nonsyn.csv', sep='\t')
M2_nonsyn_18_len = len(M2_nonsyn_18)
NS1_nonsyn_18 = pd.read_csv('18/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_18_len = len(NS1_nonsyn_18)
NEP_nonsyn_18 = pd.read_csv('18/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_18_len = len(NEP_nonsyn_18)

syn_total_18 = PB2_syn_18_len + PB1_syn_18_len + PA_syn_18_len + HA_syn_18_len + NP_syn_18_len + NA_syn_18_len + M1_syn_18_len + NS1_syn_18_len + NEP_syn_18_len
nonsyn_total_18 = PB2_nonsyn_18_len + PB1_nonsyn_18_len + PA_nonsyn_18_len + HA_nonsyn_18_len + NP_nonsyn_18_len + NA_nonsyn_18_len + M2_nonsyn_18_len + NS1_nonsyn_18_len + NEP_nonsyn_18_len

print(syn_total_18)
print(nonsyn_total_18)
##
# Out:
# 20
# 22

# %%
# ferret 19

PB2_syn_19 = pd.read_csv('19/PB2__syn.csv', sep='\t')
PB2_syn_19_len = len(PB2_syn_19)
# PB1_syn_19 = pd.read_csv('19/PB1__syn.csv', sep='\t')
# PB1_syn_19_len = len(PB1_syn_19)
# PA_syn_19 = pd.read_csv('19/PA__syn.csv', sep='\t')
# PA_syn_19_len = len(PA_syn_19)
HA_syn_19 = pd.read_csv('19/HA__syn.csv', sep='\t')
HA_syn_19_len = len(HA_syn_19)
# NP_syn_19 = pd.read_csv('19/NP__syn.csv', sep='\t')
# NP_syn_19_len = len(NP_syn_19)
NA_syn_19 = pd.read_csv('19/NA__syn.csv', sep='\t')
NA_syn_19_len = len(NA_syn_19)
# M1_syn_19 = pd.read_csv('19/M1__syn.csv', sep='\t')
# M1_syn_19_len = len(M1_syn_19)
# M2_syn_19 = pd.read_csv('19/M2__syn.csv', sep='\t')
# M2_syn_19_len = len(M2_syn_19)
# NS1_syn_19 = pd.read_csv('19/NS1__syn.csv', sep='\t')
# NS1_syn_19_len = len(NS1_syn_19)
# NEP_syn_19 = pd.read_csv('19/NEP__syn.csv', sep='\t')
# NEP_syn_19_len = len(NEP_syn_19)

# PB2_nonsyn_19 = pd.read_csv('19/PB2__nonsyn.csv', sep='\t')
# PB2_nonsyn_19_len = len(PB2_nonsyn_19)
PB1_nonsyn_19 = pd.read_csv('19/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_19_len = len(PB1_nonsyn_19)
# PA_nonsyn_19 = pd.read_csv('19/PA__nonsyn.csv', sep='\t')
# PA_nonsyn_19_len = len(PA_nonsyn_19)
HA_nonsyn_19 = pd.read_csv('19/HA__nonsyn.csv', sep='\t')
HA_nonsyn_19_len = len(HA_nonsyn_19)
NP_nonsyn_19 = pd.read_csv('19/NP__nonsyn.csv', sep='\t')
NP_nonsyn_19_len = len(NP_nonsyn_19)
NA_nonsyn_19 = pd.read_csv('19/NA__nonsyn.csv', sep='\t')
NA_nonsyn_19_len = len(NA_nonsyn_19)
M1_nonsyn_19 = pd.read_csv('19/M1__nonsyn.csv', sep='\t')
M1_nonsyn_19_len = len(M1_nonsyn_19)
# M2_nonsyn_19 = pd.read_csv('19/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_19_len = len(M2_nonsyn_19)
NS1_nonsyn_19 = pd.read_csv('19/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_19_len = len(NS1_nonsyn_19)
# NEP_nonsyn_19 = pd.read_csv('19/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_19_len = len(NEP_nonsyn_19)

syn_total_19 = PB2_syn_19_len + HA_syn_19_len + NA_syn_19_len
nonsyn_total_19 = PB1_nonsyn_19_len + HA_nonsyn_19_len + NP_nonsyn_19_len + NA_nonsyn_19_len + M1_nonsyn_19_len + NS1_nonsyn_19_len

print(syn_total_19)
print(nonsyn_total_19)
##
# Out:
# 9
# 6

# %%
# ferret 21

PB2_syn_21 = pd.read_csv('21/PB2__syn.csv', sep='\t')
PB2_syn_21_len = len(PB2_syn_21)
PB1_syn_21 = pd.read_csv('21/PB1__syn.csv', sep='\t')
PB1_syn_21_len = len(PB1_syn_21)
# PA_syn_21 = pd.read_csv('21/PA__syn.csv', sep='\t')
# PA_syn_21_len = len(PA_syn_21)
HA_syn_21 = pd.read_csv('21/HA__syn.csv', sep='\t')
HA_syn_21_len = len(HA_syn_21)
NP_syn_21 = pd.read_csv('21/NP__syn.csv', sep='\t')
NP_syn_21_len = len(NP_syn_21)
NA_syn_21 = pd.read_csv('21/NA__syn.csv', sep='\t')
NA_syn_21_len = len(NA_syn_21)
# M1_syn_21 = pd.read_csv('21/M1__syn.csv', sep='\t')
# M1_syn_21_len = len(M1_syn_21)
# M2_syn_21 = pd.read_csv('21/M2__syn.csv', sep='\t')
# M2_syn_21_len = len(M2_syn_21)
# # NS1_syn_21 = pd.read_csv('21/NS1__syn.csv', sep='\t')
# # NS1_syn_21_len = len(NS1_syn_21)
# NEP_syn_21 = pd.read_csv('21/NEP__syn.csv', sep='\t')
# NEP_syn_21_len = len(NEP_syn_21)

# PB2_nonsyn_21 = pd.read_csv('21/PB2__nonsyn.csv', sep='\t')
# PB2_nonsyn_21_len = len(PB2_nonsyn_21)
# PB1_nonsyn_21 = pd.read_csv('21/PB1__nonsyn.csv', sep='\t')
# PB1_nonsyn_21_len = len(PB1_nonsyn_21)
# PA_nonsyn_21 = pd.read_csv('21/PA__nonsyn.csv', sep='\t')
# PA_nonsyn_21_len = len(PA_nonsyn_21)
HA_nonsyn_21 = pd.read_csv('21/HA__nonsyn.csv', sep='\t')
HA_nonsyn_21_len = len(HA_nonsyn_21)
NP_nonsyn_21 = pd.read_csv('21/NP__nonsyn.csv', sep='\t')
NP_nonsyn_21_len = len(NP_nonsyn_21)
NA_nonsyn_21 = pd.read_csv('21/NA__nonsyn.csv', sep='\t')
NA_nonsyn_21_len = len(NA_nonsyn_21)
# M1_nonsyn_21 = pd.read_csv('21/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_21_len = len(M1_nonsyn_21)
# M2_nonsyn_21 = pd.read_csv('21/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_21_len = len(M2_nonsyn_21)
NS1_nonsyn_21 = pd.read_csv('21/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_21_len = len(NS1_nonsyn_21)
# NEP_nonsyn_21 = pd.read_csv('21/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_21_len = len(NEP_nonsyn_21)

syn_total_21 = PB2_syn_21_len + PB1_syn_21_len + HA_syn_21_len + NP_syn_21_len + NA_syn_21_len
nonsyn_total_21 = HA_nonsyn_21_len + NP_nonsyn_21_len + NA_nonsyn_21_len + NS1_nonsyn_21_len
print(syn_total_21)
print(nonsyn_total_21)
##
# Out:
# 8
# 6

# %%
# ferret 22

PB2_syn_22 = pd.read_csv('22/PB2__syn.csv', sep='\t')
PB2_syn_22_len = len(PB2_syn_22)
PB1_syn_22 = pd.read_csv('22/PB1__syn.csv', sep='\t')
PB1_syn_22_len = len(PB1_syn_22)
PA_syn_22 = pd.read_csv('22/PA__syn.csv', sep='\t')
PA_syn_22_len = len(PA_syn_22)
HA_syn_22 = pd.read_csv('22/HA__syn.csv', sep='\t')
HA_syn_22_len = len(HA_syn_22)
NP_syn_22 = pd.read_csv('22/NP__syn.csv', sep='\t')
NP_syn_22_len = len(NP_syn_22)
NA_syn_22 = pd.read_csv('22/NA__syn.csv', sep='\t')
NA_syn_22_len = len(NA_syn_22)
# M1_syn_22 = pd.read_csv('22/M1__syn.csv', sep='\t')
# M1_syn_22_len = len(M1_syn_22)
# M2_syn_22 = pd.read_csv('22/M2__syn.csv', sep='\t')
# M2_syn_22_len = len(M2_syn_22)
# NS1_syn_22 = pd.read_csv('22/NS1__syn.csv', sep='\t')
# NS1_syn_22_len = len(NS1_syn_22)
# NEP_syn_22 = pd.read_csv('22/NEP__syn.csv', sep='\t')
# NEP_syn_22_len = len(NEP_syn_22)

PB2_nonsyn_22 = pd.read_csv('22/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_22_len = len(PB2_nonsyn_22)
PB1_nonsyn_22 = pd.read_csv('22/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_22_len = len(PB1_nonsyn_22)
# PA_nonsyn_22 = pd.read_csv('22/PA__nonsyn.csv', sep='\t')
# PA_nonsyn_22_len = len(PA_nonsyn_22)
HA_nonsyn_22 = pd.read_csv('22/HA__nonsyn.csv', sep='\t')
HA_nonsyn_22_len = len(HA_nonsyn_22)
NP_nonsyn_22 = pd.read_csv('22/NP__nonsyn.csv', sep='\t')
NP_nonsyn_22_len = len(NP_nonsyn_22)
NA_nonsyn_22 = pd.read_csv('22/NA__nonsyn.csv', sep='\t')
NA_nonsyn_22_len = len(NA_nonsyn_22)
# M1_nonsyn_22 = pd.read_csv('22/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_22_len = len(M1_nonsyn_22)
# M2_nonsyn_22 = pd.read_csv('22/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_22_len = len(M2_nonsyn_22)
NS1_nonsyn_22 = pd.read_csv('22/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_22_len = len(NS1_nonsyn_22)
NEP_nonsyn_22 = pd.read_csv('22/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_22_len = len(NEP_nonsyn_22)

syn_total_22 = PB2_syn_22_len + PB1_syn_22_len + PA_syn_22_len + HA_syn_22_len + NP_syn_22_len + NA_syn_22_len
nonsyn_total_22 = PB2_nonsyn_22_len + PB1_nonsyn_22_len + HA_nonsyn_22_len + NP_nonsyn_22_len + NA_nonsyn_22_len + NS1_nonsyn_22_len + NEP_nonsyn_22_len

print(syn_total_22)
print(nonsyn_total_22)
##
# Out:
# 10
# 15

# %%
# ferret 23

PB2_syn_23 = pd.read_csv('23/PB2__syn.csv', sep='\t')
PB2_syn_23_len = len(PB2_syn_23)
PB1_syn_23 = pd.read_csv('23/PB1__syn.csv', sep='\t')
PB1_syn_23_len = len(PB1_syn_23)
# PA_syn_23 = pd.read_csv('23/PA__syn.csv', sep='\t')
# PA_syn_23_len = len(PA_syn_23)
HA_syn_23 = pd.read_csv('23/HA__syn.csv', sep='\t')
HA_syn_23_len = len(HA_syn_23)
# NP_syn_23 = pd.read_csv('23/NP__syn.csv', sep='\t')
# NP_syn_23_len = len(NP_syn_23)
NA_syn_23 = pd.read_csv('23/NA__syn.csv', sep='\t')
NA_syn_23_len = len(NA_syn_23)
M1_syn_23 = pd.read_csv('23/M1__syn.csv', sep='\t')
M1_syn_23_len = len(M1_syn_23)
# M2_syn_23 = pd.read_csv('23/M2__syn.csv', sep='\t')
# M2_syn_23_len = len(M2_syn_23)
# NS1_syn_23 = pd.read_csv('23/NS1__syn.csv', sep='\t')
# NS1_syn_23_len = len(NS1_syn_23)
NEP_syn_23 = pd.read_csv('23/NEP__syn.csv', sep='\t')
NEP_syn_23_len = len(NEP_syn_23)

PB2_nonsyn_23 = pd.read_csv('23/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_23_len = len(PB2_nonsyn_23)
PB1_nonsyn_23 = pd.read_csv('23/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_23_len = len(PB1_nonsyn_23)
# PA_nonsyn_23 = pd.read_csv('23/PA__nonsyn.csv', sep='\t')
# PA_nonsyn_23_len = len(PA_nonsyn_23)
HA_nonsyn_23 = pd.read_csv('23/HA__nonsyn.csv', sep='\t')
HA_nonsyn_23_len = len(HA_nonsyn_23)
NP_nonsyn_23 = pd.read_csv('23/NP__nonsyn.csv', sep='\t')
NP_nonsyn_23_len = len(NP_nonsyn_23)
NA_nonsyn_23 = pd.read_csv('23/NA__nonsyn.csv', sep='\t')
NA_nonsyn_23_len = len(NA_nonsyn_23)
M1_nonsyn_23 = pd.read_csv('23/M1__nonsyn.csv', sep='\t')
M1_nonsyn_23_len = len(M1_nonsyn_23)
# M2_nonsyn_23 = pd.read_csv('23/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_23_len = len(M2_nonsyn_23)
# NS1_nonsyn_23 = pd.read_csv('23/NS1__nonsyn.csv', sep='\t')
# NS1_nonsyn_23_len = len(NS1_nonsyn_23)
# NEP_nonsyn_23 = pd.read_csv('23/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_23_len = len(NEP_nonsyn_23)

syn_total_23 = PB2_syn_23_len + PB1_syn_23_len + HA_syn_23_len + NA_syn_23_len + M1_syn_23_len + NEP_syn_23_len
nonsyn_total_23 = PB2_nonsyn_23_len + PB1_nonsyn_23_len + HA_nonsyn_23_len + NP_nonsyn_23_len + NA_nonsyn_23_len + M1_nonsyn_23_len

print(syn_total_23)
print(nonsyn_total_23)
##
# Out:
# 11
# 16

# %%
# ferret 3

PB2_syn_25 = pd.read_csv('25/PB2__syn.csv', sep='\t')
PB2_syn_25_len = len(PB2_syn_25)
PB1_syn_25 = pd.read_csv('25/PB1__syn.csv', sep='\t')
PB1_syn_25_len = len(PB1_syn_25)
PA_syn_25 = pd.read_csv('25/PA__syn.csv', sep='\t')
PA_syn_25_len = len(PA_syn_25)
HA_syn_25 = pd.read_csv('25/HA__syn.csv', sep='\t')
HA_syn_25_len = len(HA_syn_25)
NP_syn_25 = pd.read_csv('25/NP__syn.csv', sep='\t')
NP_syn_25_len = len(NP_syn_25)
NA_syn_25 = pd.read_csv('25/NA__syn.csv', sep='\t')
NA_syn_25_len = len(NA_syn_25)
M1_syn_25 = pd.read_csv('25/M1__syn.csv', sep='\t')
M1_syn_25_len = len(M1_syn_25)
# M2_syn_25 = pd.read_csv('25/M2__syn.csv', sep='\t')
# M2_syn_25_len = len(M2_syn_25)
NS1_syn_25 = pd.read_csv('25/NS1__syn.csv', sep='\t')
NS1_syn_25_len = len(NS1_syn_25)
NEP_syn_25 = pd.read_csv('25/NEP__syn.csv', sep='\t')
NEP_syn_25_len = len(NEP_syn_25)

PB2_nonsyn_25 = pd.read_csv('25/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_25_len = len(PB2_nonsyn_25)
PB1_nonsyn_25 = pd.read_csv('25/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_25_len = len(PB1_nonsyn_25)
PA_nonsyn_25 = pd.read_csv('25/PA__nonsyn.csv', sep='\t')
PA_nonsyn_25_len = len(PA_nonsyn_25)
HA_nonsyn_25 = pd.read_csv('25/HA__nonsyn.csv', sep='\t')
HA_nonsyn_25_len = len(HA_nonsyn_25)
NP_nonsyn_25 = pd.read_csv('25/NP__nonsyn.csv', sep='\t')
NP_nonsyn_25_len = len(NP_nonsyn_25)
NA_nonsyn_25 = pd.read_csv('25/NA__nonsyn.csv', sep='\t')
NA_nonsyn_25_len = len(NA_nonsyn_25)
M1_nonsyn_25 = pd.read_csv('25/M1__nonsyn.csv', sep='\t')
M1_nonsyn_25_len = len(M1_nonsyn_25)
M2_nonsyn_25 = pd.read_csv('25/M2__nonsyn.csv', sep='\t')
M2_nonsyn_25_len = len(M2_nonsyn_25)
NS1_nonsyn_25 = pd.read_csv('25/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_25_len = len(NS1_nonsyn_25)
# NEP_nonsyn_25 = pd.read_csv('25/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_25_len = len(NEP_nonsyn_25)

syn_total_25 = PB2_syn_25_len + PB1_syn_25_len + PA_syn_25_len + HA_syn_25_len + NP_syn_25_len + NA_syn_25_len + M1_syn_25_len + NS1_syn_25_len + NEP_syn_25_len
nonsyn_total_25 = PB2_nonsyn_25_len + PB1_nonsyn_25_len + PA_nonsyn_25_len + HA_nonsyn_25_len + NP_nonsyn_25_len + NA_nonsyn_25_len + M1_nonsyn_25_len + M2_nonsyn_25_len + NS1_nonsyn_25_len

print(syn_total_25)
print(nonsyn_total_25)
##
# Out:
# 102
# 75

# %%
# ferret 3

PB2_syn_27 = pd.read_csv('27/PB2__syn.csv', sep='\t')
PB2_syn_27_len = len(PB2_syn_27)
PB1_syn_27 = pd.read_csv('27/PB1__syn.csv', sep='\t')
PB1_syn_27_len = len(PB1_syn_27)
PA_syn_27 = pd.read_csv('27/PA__syn.csv', sep='\t')
PA_syn_27_len = len(PA_syn_27)
HA_syn_27 = pd.read_csv('27/HA__syn.csv', sep='\t')
HA_syn_27_len = len(HA_syn_27)
NP_syn_27 = pd.read_csv('27/NP__syn.csv', sep='\t')
NP_syn_27_len = len(NP_syn_27)
NA_syn_27 = pd.read_csv('27/NA__syn.csv', sep='\t')
NA_syn_27_len = len(NA_syn_27)
M1_syn_27 = pd.read_csv('27/M1__syn.csv', sep='\t')
M1_syn_27_len = len(M1_syn_27)
M2_syn_27 = pd.read_csv('27/M2__syn.csv', sep='\t')
M2_syn_27_len = len(M2_syn_27)
NS1_syn_27 = pd.read_csv('27/NS1__syn.csv', sep='\t')
NS1_syn_27_len = len(NS1_syn_27)
NEP_syn_27 = pd.read_csv('27/NEP__syn.csv', sep='\t')
NEP_syn_27_len = len(NEP_syn_27)

PB2_nonsyn_27 = pd.read_csv('27/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_27_len = len(PB2_nonsyn_27)
PB1_nonsyn_27 = pd.read_csv('27/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_27_len = len(PB1_nonsyn_27)
PA_nonsyn_27 = pd.read_csv('27/PA__nonsyn.csv', sep='\t')
PA_nonsyn_27_len = len(PA_nonsyn_27)
HA_nonsyn_27 = pd.read_csv('27/HA__nonsyn.csv', sep='\t')
HA_nonsyn_27_len = len(HA_nonsyn_27)
NP_nonsyn_27 = pd.read_csv('27/NP__nonsyn.csv', sep='\t')
NP_nonsyn_27_len = len(NP_nonsyn_27)
NA_nonsyn_27 = pd.read_csv('27/NA__nonsyn.csv', sep='\t')
NA_nonsyn_27_len = len(NA_nonsyn_27)
M1_nonsyn_27 = pd.read_csv('27/M1__nonsyn.csv', sep='\t')
M1_nonsyn_27_len = len(M1_nonsyn_27)
M2_nonsyn_27 = pd.read_csv('27/M2__nonsyn.csv', sep='\t')
M2_nonsyn_27_len = len(M2_nonsyn_27)
NS1_nonsyn_27 = pd.read_csv('27/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_27_len = len(NS1_nonsyn_27)
NEP_nonsyn_27 = pd.read_csv('27/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_27_len = len(NEP_nonsyn_27)

syn_total_27 = PB2_syn_27_len + PB1_syn_27_len + PA_syn_27_len + HA_syn_27_len + NP_syn_27_len + NA_syn_27_len + M1_syn_27_len + M2_syn_27_len + NS1_syn_27_len + NEP_syn_27_len
nonsyn_total_27 = PB2_nonsyn_27_len + PB1_nonsyn_27_len + PA_nonsyn_27_len + HA_nonsyn_27_len + NP_nonsyn_27_len + NA_nonsyn_27_len + M1_nonsyn_27_len + M2_nonsyn_27_len + NS1_nonsyn_27_len + NEP_nonsyn_27_len

print(syn_total_27)
print(nonsyn_total_27)
##
# Out:
# 103
# 83

# %%
# ferret 28

PB2_syn_28 = pd.read_csv('28/PB2__syn.csv', sep='\t')
PB2_syn_28_len = len(PB2_syn_28)
PB1_syn_28 = pd.read_csv('28/PB1__syn.csv', sep='\t')
PB1_syn_28_len = len(PB1_syn_28)
PA_syn_28 = pd.read_csv('28/PA__syn.csv', sep='\t')
PA_syn_28_len = len(PA_syn_28)
# HA_syn_28 = pd.read_csv('28/HA__syn.csv', sep='\t')
# HA_syn_28_len = len(HA_syn_28)
NP_syn_28 = pd.read_csv('28/NP__syn.csv', sep='\t')
NP_syn_28_len = len(NP_syn_28)
# NA_syn_28 = pd.read_csv('28/NA__syn.csv', sep='\t')
# NA_syn_28_len = len(NA_syn_28)
M1_syn_28 = pd.read_csv('28/M1__syn.csv', sep='\t')
M1_syn_28_len = len(M1_syn_28)
M2_syn_28 = pd.read_csv('28/M2__syn.csv', sep='\t')
M2_syn_28_len = len(M2_syn_28)
NS1_syn_28 = pd.read_csv('28/NS1__syn.csv', sep='\t')
NS1_syn_28_len = len(NS1_syn_28)
NEP_syn_28 = pd.read_csv('28/NEP__syn.csv', sep='\t')
NEP_syn_28_len = len(NEP_syn_28)

PB2_nonsyn_28 = pd.read_csv('28/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_28_len = len(PB2_nonsyn_28)
PB1_nonsyn_28 = pd.read_csv('28/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_28_len = len(PB1_nonsyn_28)
PA_nonsyn_28 = pd.read_csv('28/PA__nonsyn.csv', sep='\t')
PA_nonsyn_28_len = len(PA_nonsyn_28)
HA_nonsyn_28 = pd.read_csv('28/HA__nonsyn.csv', sep='\t')
HA_nonsyn_28_len = len(HA_nonsyn_28)
# NP_nonsyn_28 = pd.read_csv('28/NP__nonsyn.csv', sep='\t')
# NP_nonsyn_28_len = len(NP_nonsyn_28)
NA_nonsyn_28 = pd.read_csv('28/NA__nonsyn.csv', sep='\t')
NA_nonsyn_28_len = len(NA_nonsyn_28)
M1_nonsyn_28 = pd.read_csv('28/M1__nonsyn.csv', sep='\t')
M1_nonsyn_28_len = len(M1_nonsyn_28)
M2_nonsyn_28 = pd.read_csv('28/M2__nonsyn.csv', sep='\t')
M2_nonsyn_28_len = len(M2_nonsyn_28)
NS1_nonsyn_28 = pd.read_csv('28/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_28_len = len(NS1_nonsyn_28)
NEP_nonsyn_28 = pd.read_csv('28/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_28_len = len(NEP_nonsyn_28)

syn_total_28 = PB2_syn_28_len + PB1_syn_28_len + PA_syn_28_len + NP_syn_28_len + M1_syn_28_len + M2_syn_28_len + NS1_syn_28_len + NEP_syn_28_len
nonsyn_total_28 = PB2_nonsyn_28_len + PB1_nonsyn_28_len + PA_nonsyn_28_len + HA_nonsyn_28_len + NA_nonsyn_28_len + M1_nonsyn_28_len + M2_nonsyn_28_len + NS1_nonsyn_28_len + NEP_nonsyn_28_len

print(syn_total_28)
print(nonsyn_total_28)
##
# Out:
# 68
# 20

# %%
# ferret 29

PB2_syn_29 = pd.read_csv('29/PB2__syn.csv', sep='\t')
PB2_syn_29_len = len(PB2_syn_29)
PB1_syn_29 = pd.read_csv('29/PB1__syn.csv', sep='\t')
PB1_syn_29_len = len(PB1_syn_29)
PA_syn_29 = pd.read_csv('29/PA__syn.csv', sep='\t')
PA_syn_29_len = len(PA_syn_29)
HA_syn_29 = pd.read_csv('29/HA__syn.csv', sep='\t')
HA_syn_29_len = len(HA_syn_29)
NP_syn_29 = pd.read_csv('29/NP__syn.csv', sep='\t')
NP_syn_29_len = len(NP_syn_29)
NA_syn_29 = pd.read_csv('29/NA__syn.csv', sep='\t')
NA_syn_29_len = len(NA_syn_29)
M1_syn_29 = pd.read_csv('29/M1__syn.csv', sep='\t')
M1_syn_29_len = len(M1_syn_29)
M2_syn_29 = pd.read_csv('29/M2__syn.csv', sep='\t')
M2_syn_29_len = len(M2_syn_29)
NS1_syn_29 = pd.read_csv('29/NS1__syn.csv', sep='\t')
NS1_syn_29_len = len(NS1_syn_29)
NEP_syn_29 = pd.read_csv('29/NEP__syn.csv', sep='\t')
NEP_syn_29_len = len(NEP_syn_29)

PB2_nonsyn_29 = pd.read_csv('29/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_29_len = len(PB2_nonsyn_29)
PB1_nonsyn_29 = pd.read_csv('29/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_29_len = len(PB1_nonsyn_29)
PA_nonsyn_29 = pd.read_csv('29/PA__nonsyn.csv', sep='\t')
PA_nonsyn_29_len = len(PA_nonsyn_29)
HA_nonsyn_29 = pd.read_csv('29/HA__nonsyn.csv', sep='\t')
HA_nonsyn_29_len = len(HA_nonsyn_29)
NP_nonsyn_29 = pd.read_csv('29/NP__nonsyn.csv', sep='\t')
NP_nonsyn_29_len = len(NP_nonsyn_29)
NA_nonsyn_29 = pd.read_csv('29/NA__nonsyn.csv', sep='\t')
NA_nonsyn_29_len = len(NA_nonsyn_29)
M1_nonsyn_29 = pd.read_csv('29/M1__nonsyn.csv', sep='\t')
M1_nonsyn_29_len = len(M1_nonsyn_29)
M2_nonsyn_29 = pd.read_csv('29/M2__nonsyn.csv', sep='\t')
M2_nonsyn_29_len = len(M2_nonsyn_29)
NS1_nonsyn_29 = pd.read_csv('29/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_29_len = len(NS1_nonsyn_29)
NEP_nonsyn_29 = pd.read_csv('29/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_29_len = len(NEP_nonsyn_29)

syn_total_29 = PB2_syn_29_len + PB1_syn_29_len + PA_syn_29_len + HA_syn_29_len + NP_syn_29_len + NA_syn_29_len + M1_syn_29_len + M2_syn_29_len + NS1_syn_29_len + NEP_syn_29_len
nonsyn_total_29 = PB2_nonsyn_29_len + PB1_nonsyn_29_len + PA_nonsyn_29_len + HA_nonsyn_29_len + NP_nonsyn_29_len + NA_nonsyn_29_len + M1_nonsyn_29_len + M2_nonsyn_29_len + NS1_nonsyn_29_len + NEP_nonsyn_29_len

print(syn_total_29)
print(nonsyn_total_29)
##
# Out:
# 117
# 78

# %%
# ferret 31

PB2_syn_31 = pd.read_csv('31/PB2__syn.csv', sep='\t')
PB2_syn_31_len = len(PB2_syn_31)
PB1_syn_31 = pd.read_csv('31/PB1__syn.csv', sep='\t')
PB1_syn_31_len = len(PB1_syn_31)
PA_syn_31 = pd.read_csv('31/PA__syn.csv', sep='\t')
PA_syn_31_len = len(PA_syn_31)
HA_syn_31 = pd.read_csv('31/HA__syn.csv', sep='\t')
HA_syn_31_len = len(HA_syn_31)
NP_syn_31 = pd.read_csv('31/NP__syn.csv', sep='\t')
NP_syn_31_len = len(NP_syn_31)
NA_syn_31 = pd.read_csv('31/NA__syn.csv', sep='\t')
NA_syn_31_len = len(NA_syn_31)
M1_syn_31 = pd.read_csv('31/M1__syn.csv', sep='\t')
M1_syn_31_len = len(M1_syn_31)
M2_syn_31 = pd.read_csv('31/M2__syn.csv', sep='\t')
M2_syn_31_len = len(M2_syn_31)
NS1_syn_31 = pd.read_csv('31/NS1__syn.csv', sep='\t')
NS1_syn_31_len = len(NS1_syn_31)
# NEP_syn_31 = pd.read_csv('31/NEP__syn.csv', sep='\t')
# NEP_syn_31_len = len(NEP_syn_31)

PB2_nonsyn_31 = pd.read_csv('31/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_31_len = len(PB2_nonsyn_31)
PB1_nonsyn_31 = pd.read_csv('31/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_31_len = len(PB1_nonsyn_31)
PA_nonsyn_31 = pd.read_csv('31/PA__nonsyn.csv', sep='\t')
PA_nonsyn_31_len = len(PA_nonsyn_31)
HA_nonsyn_31 = pd.read_csv('31/HA__nonsyn.csv', sep='\t')
HA_nonsyn_31_len = len(HA_nonsyn_31)
NP_nonsyn_31 = pd.read_csv('31/NP__nonsyn.csv', sep='\t')
NP_nonsyn_31_len = len(NP_nonsyn_31)
NA_nonsyn_31 = pd.read_csv('31/NA__nonsyn.csv', sep='\t')
NA_nonsyn_31_len = len(NA_nonsyn_31)
M1_nonsyn_31 = pd.read_csv('31/M1__nonsyn.csv', sep='\t')
M1_nonsyn_31_len = len(M1_nonsyn_31)
M2_nonsyn_31 = pd.read_csv('31/M2__nonsyn.csv', sep='\t')
M2_nonsyn_31_len = len(M2_nonsyn_31)
NS1_nonsyn_31 = pd.read_csv('31/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_31_len = len(NS1_nonsyn_31)
# NEP_nonsyn_31 = pd.read_csv('31/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_31_len = len(NEP_nonsyn_31)

syn_total_31 = PB2_syn_31_len + PB1_syn_31_len + PA_syn_31_len + HA_syn_31_len + NP_syn_31_len + NA_syn_31_len + M1_syn_31_len + M2_syn_31_len + NS1_syn_31_len
nonsyn_total_31 = PB2_nonsyn_31_len + PB1_nonsyn_31_len + PA_nonsyn_31_len + HA_nonsyn_31_len + NP_nonsyn_31_len + NA_nonsyn_31_len + M1_nonsyn_31_len + M2_nonsyn_31_len + NS1_nonsyn_31_len

print(syn_total_31)
print(nonsyn_total_31)
##
# Out:
# 74
# 56

# %%
# ferret 33

# PB2_syn_33 = pd.read_csv('33/PB2__syn.csv', sep='\t')
# PB2_syn_33_len = len(PB2_syn_33)
PB1_syn_33 = pd.read_csv('33/PB1__syn.csv', sep='\t')
PB1_syn_33_len = len(PB1_syn_33)
PA_syn_33 = pd.read_csv('33/PA__syn.csv', sep='\t')
PA_syn_33_len = len(PA_syn_33)
HA_syn_33 = pd.read_csv('33/HA__syn.csv', sep='\t')
HA_syn_33_len = len(HA_syn_33)
NP_syn_33 = pd.read_csv('33/NP__syn.csv', sep='\t')
NP_syn_33_len = len(NP_syn_33)
# NA_syn_33 = pd.read_csv('33/NA__syn.csv', sep='\t')
# NA_syn_33_len = len(NA_syn_33)
# M1_syn_33 = pd.read_csv('33/M1__syn.csv', sep='\t')
# M1_syn_33_len = len(M1_syn_33)
# M2_syn_33 = pd.read_csv('33/M2__syn.csv', sep='\t')
# M2_syn_33_len = len(M2_syn_33)
NS1_syn_33 = pd.read_csv('33/NS1__syn.csv', sep='\t')
NS1_syn_33_len = len(NS1_syn_33)
# NEP_syn_33 = pd.read_csv('33/NEP__syn.csv', sep='\t')
# NEP_syn_33_len = len(NEP_syn_33)

# PB2_nonsyn_33 = pd.read_csv('33/PB2__nonsyn.csv', sep='\t')
# PB2_nonsyn_33_len = len(PB2_nonsyn_33)
PB1_nonsyn_33 = pd.read_csv('33/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_33_len = len(PB1_nonsyn_33)
PA_nonsyn_33 = pd.read_csv('33/PA__nonsyn.csv', sep='\t')
PA_nonsyn_33_len = len(PA_nonsyn_33)
HA_nonsyn_33 = pd.read_csv('33/HA__nonsyn.csv', sep='\t')
HA_nonsyn_33_len = len(HA_nonsyn_33)
NP_nonsyn_33 = pd.read_csv('33/NP__nonsyn.csv', sep='\t')
NP_nonsyn_33_len = len(NP_nonsyn_33)
# NA_nonsyn_33 = pd.read_csv('33/NA__nonsyn.csv', sep='\t')
# NA_nonsyn_33_len = len(NA_nonsyn_33)
# M1_nonsyn_33 = pd.read_csv('33/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_33_len = len(M1_nonsyn_33)
# M2_nonsyn_33 = pd.read_csv('33/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_33_len = len(M2_nonsyn_33)
# NS1_nonsyn_33 = pd.read_csv('33/NS1__nonsyn.csv', sep='\t')
# NS1_nonsyn_33_len = len(NS1_nonsyn_33)
NEP_nonsyn_33 = pd.read_csv('33/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_33_len = len(NEP_nonsyn_33)

syn_total_33 = PB1_syn_33_len + PA_syn_33_len + HA_syn_33_len + NP_syn_33_len + NS1_syn_33_len
nonsyn_total_33 = PB1_nonsyn_33_len + PA_nonsyn_33_len + HA_nonsyn_33_len + NP_nonsyn_33_len + NEP_nonsyn_33_len

print(syn_total_33)
print(nonsyn_total_33)
##
# Out:
# 13
# 22

# %%
# ferret 35

PB2_syn_35 = pd.read_csv('35/PB2__syn.csv', sep='\t')
PB2_syn_35_len = len(PB2_syn_35)
PB1_syn_35 = pd.read_csv('35/PB1__syn.csv', sep='\t')
PB1_syn_35_len = len(PB1_syn_35)
PA_syn_35 = pd.read_csv('35/PA__syn.csv', sep='\t')
PA_syn_35_len = len(PA_syn_35)
HA_syn_35 = pd.read_csv('35/HA__syn.csv', sep='\t')
HA_syn_35_len = len(HA_syn_35)
NP_syn_35 = pd.read_csv('35/NP__syn.csv', sep='\t')
NP_syn_35_len = len(NP_syn_35)
# NA_syn_35 = pd.read_csv('35/NA__syn.csv', sep='\t')
# NA_syn_35_len = len(NA_syn_35)
M1_syn_35 = pd.read_csv('35/M1__syn.csv', sep='\t')
M1_syn_35_len = len(M1_syn_35)
# M2_syn_35 = pd.read_csv('35/M2__syn.csv', sep='\t')
# M2_syn_35_len = len(M2_syn_35)
NS1_syn_35 = pd.read_csv('35/NS1__syn.csv', sep='\t')
NS1_syn_35_len = len(NS1_syn_35)
# NEP_syn_35 = pd.read_csv('35/NEP__syn.csv', sep='\t')
# NEP_syn_35_len = len(NEP_syn_35)

PB2_nonsyn_35 = pd.read_csv('35/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_35_len = len(PB2_nonsyn_35)
PB1_nonsyn_35 = pd.read_csv('35/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_35_len = len(PB1_nonsyn_35)
PA_nonsyn_35 = pd.read_csv('35/PA__nonsyn.csv', sep='\t')
PA_nonsyn_35_len = len(PA_nonsyn_35)
HA_nonsyn_35 = pd.read_csv('35/HA__nonsyn.csv', sep='\t')
HA_nonsyn_35_len = len(HA_nonsyn_35)
NP_nonsyn_35 = pd.read_csv('35/NP__nonsyn.csv', sep='\t')
NP_nonsyn_35_len = len(NP_nonsyn_35)
# NA_nonsyn_35 = pd.read_csv('35/NA__nonsyn.csv', sep='\t')
# NA_nonsyn_35_len = len(NA_nonsyn_35)
# M1_nonsyn_35 = pd.read_csv('35/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_35_len = len(M1_nonsyn_35)
M2_nonsyn_35 = pd.read_csv('35/M2__nonsyn.csv', sep='\t')
M2_nonsyn_35_len = len(M2_nonsyn_35)
# NS1_nonsyn_35 = pd.read_csv('35/NS1__nonsyn.csv', sep='\t')
# NS1_nonsyn_35_len = len(NS1_nonsyn_35)
# NEP_nonsyn_35 = pd.read_csv('35/NEP__nonsyn.csv', sep='\t')
# NEP_nonsyn_35_len = len(NEP_nonsyn_35)

syn_total_35 = PB2_syn_35_len + PB1_syn_35_len + PA_syn_35_len + HA_syn_35_len + NP_syn_35_len + M1_syn_35_len + NS1_syn_35_len
nonsyn_total_35 = PB2_nonsyn_35_len + PB1_nonsyn_35_len + PA_nonsyn_35_len + HA_nonsyn_35_len + NP_nonsyn_35_len + M2_nonsyn_35_len

print(syn_total_35)
print(nonsyn_total_35)
##
# Out:
# 13
# 23

# %%
# ferret 36

PB2_syn_36 = pd.read_csv('36/PB2__syn.csv', sep='\t')
PB2_syn_36_len = len(PB2_syn_36)
PB1_syn_36 = pd.read_csv('36/PB1__syn.csv', sep='\t')
PB1_syn_36_len = len(PB1_syn_36)
PA_syn_36 = pd.read_csv('36/PA__syn.csv', sep='\t')
PA_syn_36_len = len(PA_syn_36)
# HA_syn_36 = pd.read_csv('36/HA__syn.csv', sep='\t')
# HA_syn_36_len = len(HA_syn_36)
# NP_syn_36 = pd.read_csv('36/NP__syn.csv', sep='\t')
# NP_syn_36_len = len(NP_syn_36)
# NA_syn_36 = pd.read_csv('36/NA__syn.csv', sep='\t')
# NA_syn_36_len = len(NA_syn_36)
# M1_syn_36 = pd.read_csv('36/M1__syn.csv', sep='\t')
# M1_syn_36_len = len(M1_syn_36)
# M2_syn_36 = pd.read_csv('36/M2__syn.csv', sep='\t')
# M2_syn_36_len = len(M2_syn_36)
# NS1_syn_36 = pd.read_csv('36/NS1__syn.csv', sep='\t')
# NS1_syn_36_len = len(NS1_syn_36)
NEP_syn_36 = pd.read_csv('36/NEP__syn.csv', sep='\t')
NEP_syn_36_len = len(NEP_syn_36)

PB2_nonsyn_36 = pd.read_csv('36/PB2__nonsyn.csv', sep='\t')
PB2_nonsyn_36_len = len(PB2_nonsyn_36)
PB1_nonsyn_36 = pd.read_csv('36/PB1__nonsyn.csv', sep='\t')
PB1_nonsyn_36_len = len(PB1_nonsyn_36)
PA_nonsyn_36 = pd.read_csv('36/PA__nonsyn.csv', sep='\t')
PA_nonsyn_36_len = len(PA_nonsyn_36)
HA_nonsyn_36 = pd.read_csv('36/HA__nonsyn.csv', sep='\t')
HA_nonsyn_36_len = len(HA_nonsyn_36)
NP_nonsyn_36 = pd.read_csv('36/NP__nonsyn.csv', sep='\t')
NP_nonsyn_36_len = len(NP_nonsyn_36)
# NA_nonsyn_36 = pd.read_csv('36/NA__nonsyn.csv', sep='\t')
# NA_nonsyn_36_len = len(NA_nonsyn_36)
# M1_nonsyn_36 = pd.read_csv('36/M1__nonsyn.csv', sep='\t')
# M1_nonsyn_36_len = len(M1_nonsyn_36)
# M2_nonsyn_36 = pd.read_csv('36/M2__nonsyn.csv', sep='\t')
# M2_nonsyn_36_len = len(M2_nonsyn_36)
NS1_nonsyn_36 = pd.read_csv('36/NS1__nonsyn.csv', sep='\t')
NS1_nonsyn_36_len = len(NS1_nonsyn_36)
NEP_nonsyn_36 = pd.read_csv('36/NEP__nonsyn.csv', sep='\t')
NEP_nonsyn_36_len = len(NEP_nonsyn_36)

syn_total_36 = PB2_syn_36_len + PB1_syn_36_len + PA_syn_36_len + NEP_syn_36_len
nonsyn_total_36 = PB2_nonsyn_36_len + PB1_nonsyn_36_len + PA_nonsyn_36_len + HA_nonsyn_36_len + NP_nonsyn_36_len + NS1_nonsyn_36_len + NEP_nonsyn_36_len

print(syn_total_36)
print(nonsyn_total_36)
##
# Out:
# 6
# 17

# %%
total_syn = 69+80+18+65+79+7+7+4+6+4+4+7+11+20+9+8+10+11+102+103+68+117+74+13+13+6
total_nonsyn = 52+53+15+54+64+7+6+3+4+5+12+7+16+22+6+6+15+16+75+83+20+78+56+22+23+17
total = 915 + 737
total_index_syn = 69+80+65+79+7+4+4+4+11+9+8+11+102+103+117+74+13+13
total_index_nonsyn = 52+53+54+64+7+3+5+12+16+6+6+16+75+83+78+56+22+23
total_contact_syn = 18+7+6+7+20+10+68+6
total_contact_nonsyn = 15+6+4+7+22+15+20+17

GD3_index_syn = 69+80+65+79
GD3_index_nonsyn = 52+53+54+64
GD3_contact_syn = 18
GD3_contact_nonsyn = 15

rGD3_index_syn = 7+4+4+4+11+9+8+11
rGD3_index_nonsyn = 7+3+5+12+16+6+6+16
rGD3_contact_syn = 7+6+7+20+10
rGD3_contact_nonsyn = 6+4+7+22+15

Anhui_index_syn = 102+103+117+74
Anhui_index_nonsyn = 75+83+78+56
Anhui_contact_syn = 68
Anhui_contact_nonsyn = 20

CA04_index_syn = 13+13
CA04_index_nonsyn = 22+23
CA04_contact_syn = 6
CA04_contact_nonsyn = 17

# %%
total_syn_list = [69,80,18,65,79,7,7,4,6,4,4,7,11,20,9,8,10,11,102,103,68,117,74,13,13,6]
total_nonsyn_list = [52,53,15,54,64,7,6,3,4,5,12,7,16,22,6,6,15,16,75,83,20,78,56,22,23,17]
total = [915 , 737]
total_index_syn_list = [69,80,65,79,7,4,4,4,11,9,8,11,102,103,117,74,13,13]
total_index_nonsyn_list = [52,53,54,64,7,3,5,12,16,6,6,16,75,83,78,56,22,23]
total_contact_syn_list = [18,7,6,7,20,10,68,6]
total_contact_nonsyn_list = [15,6,4,7,22,15,20,17]

total_index_list = [89,80,65,79,7,4,4,4,11,9,8,11,102,103,117,74,13,13,52,53,54,64,7,3,5,12,16,6,6,16,75,83,78,56,22,23]
total_contact_list = [18,7,6,7,20,10,68,6,15,6,4,7,22,15,20,17]

GD3_index_syn_list = [69,80,65,79]
GD3_index_nonsyn_list = [52,53,54,64]
GD3_contact_syn_list = [18]
GD3_contact_nonsyn_list = [15]

rGD3_index_syn_list = [7,4,4,4,11,9,8,11]
rGD3_index_nonsyn_list = [7,3,5,12,16,6,6,16]
rGD3_contact_syn_list = [7,6,7,20,10]
rGD3_contact_nonsyn_list = [6,4,7,22,15]

Anhui_index_syn_list = [102,103,117,74]
Anhui_index_nonsyn_list = [75,83,78,56]
Anhui_contact_syn_list = [68]
Anhui_contact_nonsyn_list = [20]

CA04_index_syn_list = [13,13]
CA04_index_nonsyn_list = [22,23]
CA04_contact_syn_list = [6]
CA04_contact_nonsyn_list = [17]

# %%
total_syn_array = np.array(total_syn_list)
total_nonsyn_array = np.array(total_nonsyn_list)

total_index_syn_array = np.array(total_index_syn_list)
total_index_nonsyn_array = np.array(total_index_nonsyn_list)
total_contact_syn_array = np.array(total_contact_syn_list)
total_contact_nonsyn_array = np.array(total_contact_nonsyn_list)

total_index_array = np.array(total_index_list)
total_contact_array = np.array(total_contact_list)

GD3_index_syn_array = np.array(GD3_index_syn_list)
GD3_index_nonsyn_array = np.array(GD3_index_nonsyn_list)
GD3_contact_syn_array = np.array(GD3_contact_syn_list)
GD3_contact_nonsyn_array = np.array(GD3_contact_nonsyn_list)

rGD3_index_syn_array = np.array(rGD3_index_syn_list)
rGD3_index_nonsyn_array = np.array(rGD3_index_nonsyn_list)
rGD3_contact_syn_array = np.array(rGD3_contact_syn_list)
rGD3_contact_nonsyn_array = np.array(rGD3_contact_nonsyn_list)

Anhui_index_syn_array = np.array(Anhui_index_syn_list)
Anhui_index_nonsyn_array = np.array(Anhui_index_nonsyn_list)
Anhui_contact_syn_array = np.array(Anhui_contact_syn_list)
Anhui_contact_nonsyn_array = np.array(Anhui_contact_nonsyn_list)

CA04_index_syn_array = np.array(CA04_index_syn_list)
CA04_index_nonsyn_array = np.array(CA04_index_nonsyn_list)
CA04_contact_syn_array = np.array(CA04_contact_syn_list)
CA04_contact_nonsyn_array = np.array(CA04_contact_nonsyn_list)

# %%
## unpaired t-test for index and contact ferrets total
 
#For unbiased max likelihood estimate we have to divide the var by N-1, and therefore the parameter ddof = 1

var_total_index_array = total_index_array.var(ddof=1)
var_total_contact_array = total_contact_array.var(ddof=1)

#std deviation
s = np.sqrt((var_total_index_array + var_total_contact_array)/2)

## Calculate the t-statistics
t = (total_index_array.mean() - total_contact_array.mean())/(s*np.sqrt(4/26))

## Compare with the critical t-value
#Degrees of freedom
df = 26 - 2

#p-value after comparison with the t 
p = 1 - stats.t.cdf(t,df=df)

print("t = " + str(t))
print("p = " + str(2*p))
# Out:
# t = 2.2141863972842226
# p = 0.036564778486488425

# %%
# total_index_syn_array vs total_contact_syn_array 

#For unbiased max likelihood estimate we have to divide the var by N-1, and therefore the parameter ddof = 1

var_total_index_syn_array = total_index_syn_array.var(ddof=1)
var_total_contact_syn_array = total_contact_syn_array.var(ddof=1)

#std deviation
s = np.sqrt((var_total_index_syn_array + var_total_contact_syn_array)/2)

## Calculate the t-statistics
t = (total_index_syn_array.mean() - total_contact_syn_array.mean())/(s*np.sqrt(4/26))

## Compare with the critical t-value
#Degrees of freedom
df = 26 - 2

#p-value after comparison with the t 
p = 1 - stats.t.cdf(t,df=df)

print("t = " + str(t))
print("p = " + str(2*p))
# Out:
# t = 1.9483790916747254
# p = 0.06315500593443213

# %%
 # total_index_nonsyn vs total_contact_nonsyn 
#For unbiased max likelihood estimate we have to divide the var by N-1, and therefore the parameter ddof = 1

var_total_index_nonsyn_array = total_index_nonsyn_array.var(ddof=1)
var_total_contact_nonsyn_array = total_contact_nonsyn_array.var(ddof=1)

#std deviation
s = np.sqrt((var_total_index_nonsyn_array + var_total_contact_nonsyn_array)/2)

## Calculate the t-statistics
t = (total_index_nonsyn_array.mean() - total_contact_nonsyn_array.mean())/(s*np.sqrt(4/26))

## Compare with the critical t-value
#Degrees of freedom
df = 26 - 2

#p-value after comparison with the t 
p = 1 - stats.t.cdf(t,df=df)

print("t = " + str(t))
print("p = " + str(2*p))
# Out:
# t = 2.670122302237618
# p = 0.01339155091039812

# %%
a = np.random.randn(10) + 2
#Gaussian distributed data with with mean = 0 and var = 1
b = np.random.randn(10)

# %%
a
# Out:
# array([1.91860571, 3.61036518, 0.25699898, 2.53783981, 1.39134352,
#        0.2905735 , 2.3155637 , 1.06883107, 1.75264595, 1.83122352])
